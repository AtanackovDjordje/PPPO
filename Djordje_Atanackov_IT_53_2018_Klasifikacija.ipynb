# %% [markdown]
# **Predmet: Principi prezentacije i prepoznavanje oblika**
#
# **Tema: Klasifikacija**
#
# **Student:Đorđe Atanackov IT-53/2018**

# %% [markdown]
# **Klasifikacija**
#
# Klasifikacija je postupak predviđanja/određivanja klase datih tačaka podataka korišćenjem postejećeg označavanja tačaka. Klasifikacija se ubraja u kategoriju nadgledanog mašinskog učenja. U okviru mašinskog učenja, konkretno za uspešnost zadataka klasifikacije, ulazni set podataka mora biti obiman i raznovrstan.
#
# ---
#
#
#
# Dataset sadrži slike pasa raspoređenih u dva foldera, folder "train" i folder "test", kao i dva csv fajla, "labels" i "sample_submissions" u prvom se nalaze definisane slike(id) i rasu pasa(breed), dok drugi sadrži željeni krajnji izlaz programa.

# %% [markdown]
# **Importi**
#
# Definisanje neophodnih biblioteka

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=16_SPk4CIhL5tL9e3LVnzdyUT_UIwKWDl' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=16_SPk4CIhL5tL9e3LVnzdyUT_UIwKWDl" -O data.zip && rm -rf /tmp/cookies.txt
# Out:
# --2022-12-15 03:30:55--  https://docs.google.com/uc?export=download&confirm=t&id=16_SPk4CIhL5tL9e3LVnzdyUT_UIwKWDl
# Resolving docs.google.com (docs.google.com)... 142.251.16.113, 142.251.16.102, 142.251.16.101, ...
# Connecting to docs.google.com (docs.google.com)|142.251.16.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-64-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/2ejnrevra14298ct0hmba4hrt1gk2527/1671075000000/06049624160957438625/*/16_SPk4CIhL5tL9e3LVnzdyUT_UIwKWDl?e=download&uuid=e73910a3-0201-412d-80fa-b3d9b28ace69 [following]
# Warning: wildcards not supported in HTTP.
# --2022-12-15 03:30:55--  https://doc-0k-64-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/2ejnrevra14298ct0hmba4hrt1gk2527/1671075000000/06049624160957438625/*/16_SPk4CIhL5tL9e3LVnzdyUT_UIwKWDl?e=download&uuid=e73910a3-0201-412d-80fa-b3d9b28ace69
# Resolving doc-0k-64-docs.googleusercontent.com (doc-0k-64-docs.googleusercontent.com)... 172.253.63.132, 2607:f8b0:4004:c08::84
# Connecting to doc-0k-64-docs.googleusercontent.com (doc-0k-64-docs.googleusercontent.com)|172.253.63.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 724495926 (691M) [application/x-zip-compressed]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 690.93M   219MB/s    in 3.2s
#
# 2022-12-15 03:30:58 (219 MB/s) - ‘data.zip’ saved [724495926/724495926]

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
# replace labels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace labels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import numpy as np 
import pandas as pd 
import os, cv2, random, time, shutil, csv
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import gc
from tqdm import tqdm
from google.colab.patches import cv2_imshow


import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization, Dense, GlobalAveragePooling2D, Lambda, Dropout, InputLayer, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img

# %% [markdown]
# Definicija funkcije koja broji sve fajlove u folderu

# %%
def get_num_files(path):
    if not os.path.exists(path):
        return 0
    return sum([len(files) for r, d, files in os.walk(path)])

# %% [markdown]
# Učitavanje direktorijuma sa podacima:

# %%
train_dir = '/content/train'
test_dir = '/content/test'

data_size = get_num_files(train_dir)
test_size = get_num_files(test_dir)
print('Data samples size: ', data_size)
print('Test samples size: ', test_size)
# Out:
# Data samples size:  10222
# Test samples size:  10357

# %%
labels_dataframe = pd.read_csv('/content/labels.csv')

sample_df = pd.read_csv('/content/sample_submission.csv')

labels_dataframe.head(10)
# Out:
#                                  id               breed
# 0  000bec180eb18c7604dcecc8fe0dba07         boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97               dingo
# 2  001cdf01b096e06d78e9e5112d419397            pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d            bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62    golden_retriever
# 5  002211c81b498ef88e1b40b9abf84e1d  bedlington_terrier
# 6  00290d3e1fdd27226ba27a8ce248ce85  bedlington_terrier
# 7  002a283a315af96eaea0e28e7163b21b              borzoi
# 8  003df8b8a8b05244b1d920bb6cf451f9             basenji
# 9  0042188c895a2f14ef64a918ed9c7b64  scottish_deerhound

# %% [markdown]
# Prikaz jedne fotografije:

# %%
path = "/content/train/0ab9cdefc666573f8019356ffefe0c69.jpg"
img = cv2.imread(path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=550x600 at 0x7F4ED1487BB0>

# %% [markdown]
# Čitanje jedinstvenih rasa:

# %%
unique_breeds = labels_dataframe["breed"].value_counts()
print(unique_breeds)
# Out:
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
#                        ...
# golden_retriever         67
# brabancon_griffon        67
# komondor                 67
# eskimo_dog               66
# briard                   66
# Name: breed, Length: 120, dtype: int64

# %% [markdown]
# Sortiranje liste sa rasama i prikaz prvih 10

# %%
dog_breeds = sorted(list(set(labels_dataframe['breed'])))
n_classes = len(dog_breeds)
print(n_classes)
dog_breeds[:10]
# Out:
# 120
# ['affenpinscher',
#  'afghan_hound',
#  'african_hunting_dog',
#  'airedale',
#  'american_staffordshire_terrier',
#  'appenzeller',
#  'australian_terrier',
#  'basenji',
#  'basset',
#  'beagle']

# %% [markdown]
# rečnik pojmova:

# %%
class_to_num = dict(zip(dog_breeds, range(n_classes)))

# %% [markdown]
# Smeštanje slika u niz:

# %%
def images_to_array(data_dir, labels_dataframe, img_size = (224,224,3)):

  images_names = labels_dataframe['id']
  images_labels = labels_dataframe['breed']
  data_size = len(images_names)
  #initailize output arrays
  X = np.zeros([data_size, img_size[0], img_size[1], img_size[2]], dtype = np.uint8)
  Y = np.zeros([data_size,1], dtype = np.uint8)
  #read data and labels
  for i in tqdm(range(data_size)):
    image_name = images_names[i]
    img_dir = os.path.join(data_dir, image_name + '.jpg')
    img_pixels = load_img(img_dir, target_size = img_size)
    X[i] = img_pixels

    image_breed = images_labels[i]
    Y[i] = class_to_num[image_breed]

  
  Y = to_categorical(Y)
  #shuffle
  ind = np.random.permutation(data_size)
  X = X[ind]
  Y = Y[ind]
  print('Output data size: ', X.shape)
  print('Output label size: ', Y.shape)
  return X, Y
  gc.collect()

# %% [markdown]
# Definisanje rezolucije fotografija:

# %%
img_size = (250,250,3)
X, Y = images_to_array(train_dir, labels_dataframe, img_size)
# Out:
# 100%|██████████| 10222/10222 [00:38<00:00, 264.27it/s]
# Output data size:  (10222, 250, 250, 3)
# Output label size:  (10222, 120)

# %% [markdown]
# Definisanje get_features funkcije:

# %%
def get_features(model_name, data_preprocessor, input_size, data):

    #Prepare pipeline.
    input_layer = Input(input_size)
    preprocessor = Lambda(data_preprocessor)(input_layer)
    base_model = model_name(weights='imagenet', include_top=False,
                            input_shape=input_size)(preprocessor)
    avg = GlobalAveragePooling2D()(base_model)
    feature_extractor = Model(inputs = input_layer, outputs = avg)
    #Extract feature.
    feature_maps = feature_extractor.predict(data, batch_size=64, verbose=1)
    print('Feature maps shape: ', feature_maps.shape)
    return feature_maps
    gc.collect()

# %% [markdown]
# CNN

# %%
from keras.applications.inception_v3 import InceptionV3, preprocess_input
inception_preprocessor = preprocess_input
inception_features = get_features(InceptionV3,
                                  inception_preprocessor,
                                  img_size, X)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# 160/160 [==============================] - 1274s 8s/step
# Feature maps shape:  (10222, 2048)

# %%
final_features = inception_features
print('Final feature maps shape', final_features.shape)
# Out:
# Final feature maps shape (10222, 2048)

# %% [markdown]
# EarlyStopping callback

# %%
from keras.callbacks import EarlyStopping
#Prepare call backs
EarlyStop_callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
my_callback=[EarlyStop_callback]

# %% [markdown]
# **Best case**

# %%
gc.collect()
#Prepare DNN model
dnn = keras.models.Sequential([
    InputLayer(final_features.shape[1:]),
    Dropout(0.7),
    Dense(n_classes, activation='softmax')
])

dnn.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#Train simple DNN on extracted features.
h = dnn.fit(final_features, Y,
            batch_size=128,
            epochs=60,
            validation_split=0.1,
            callbacks=EarlyStop_callback)
gc.collect()
# Out:
# Epoch 1/60
# 72/72 [==============================] - 2s 15ms/step - loss: 2.6143 - accuracy: 0.4299 - val_loss: 0.6904 - val_accuracy: 0.8152
# Epoch 2/60
# 72/72 [==============================] - 1s 12ms/step - loss: 0.8280 - accuracy: 0.7645 - val_loss: 0.5563 - val_accuracy: 0.8299
# Epoch 3/60
# 72/72 [==============================] - 1s 12ms/step - loss: 0.6554 - accuracy: 0.8075 - val_loss: 0.5427 - val_accuracy: 0.8299
# Epoch 4/60
# 72/72 [==============================] - 1s 11ms/step - loss: 0.5621 - accuracy: 0.8264 - val_loss: 0.5316 - val_accuracy: 0.8416
# Epoch 5/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.5136 - accuracy: 0.8381 - val_loss: 0.5382 - val_accuracy: 0.8368
# Epoch 6/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.4441 - accuracy: 0.8581 - val_loss: 0.5305 - val_accuracy: 0.8368
# Epoch 7/60
# 72/72 [==============================] - 1s 9ms/step - loss: 0.4290 - accuracy: 0.8603 - val_loss: 0.5320 - val_accuracy: 0.8475
# Epoch 8/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.4045 - accuracy: 0.8665 - val_loss: 0.5341 - val_accuracy: 0.8407
# Epoch 9/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.3757 - accuracy: 0.8704 - val_loss: 0.5295 - val_accuracy: 0.8485
# Epoch 10/60
# 72/72 [==============================] - 1s 9ms/step - loss: 0.3576 - accuracy: 0.8780 - val_loss: 0.5252 - val_accuracy: 0.8456
# Epoch 11/60
# 72/72 [==============================] - 1s 9ms/step - loss: 0.3413 - accuracy: 0.8849 - val_loss: 0.5479 - val_accuracy: 0.8436
# Epoch 12/60
# 72/72 [==============================] - 1s 9ms/step - loss: 0.3200 - accuracy: 0.8912 - val_loss: 0.5653 - val_accuracy: 0.8338
# Epoch 13/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.3113 - accuracy: 0.8947 - val_loss: 0.5335 - val_accuracy: 0.8485
# Epoch 14/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.2957 - accuracy: 0.8986 - val_loss: 0.5838 - val_accuracy: 0.8319
# Epoch 15/60
# 72/72 [==============================] - 1s 9ms/step - loss: 0.2881 - accuracy: 0.9008 - val_loss: 0.5898 - val_accuracy: 0.8348
# Epoch 16/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.2695 - accuracy: 0.9068 - val_loss: 0.5735 - val_accuracy: 0.8416
# Epoch 17/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.2584 - accuracy: 0.9077 - val_loss: 0.5772 - val_accuracy: 0.8328
# Epoch 18/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.2507 - accuracy: 0.9121 - val_loss: 0.5798 - val_accuracy: 0.8456
# Epoch 19/60
# 72/72 [==============================] - 1s 9ms/step - loss: 0.2601 - accuracy: 0.9097 - val_loss: 0.5832 - val_accuracy: 0.8456
# Epoch 20/60
# 72/72 [==============================] - 1s 10ms/step - loss: 0.2418 - accuracy: 0.9128 - val_loss: 0.6077 - val_accuracy: 0.8368
# 1618

# %% [markdown]
# Prikaz tačnosti istreniranog modela:

# %%
keras.backend.clear_session()
plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
gc.collect()
# Out:
# 2774

# %% [markdown]
# Ponovno ubacivanje slika u niz i druga funkcija za testiranje podataka:

# %%
gc.collect()
def images_to_array2(data_dir, labels_dataframe, img_size = (224,224,3)):

    images_names = labels_dataframe['id']
    data_size = len(images_names)
    X = np.zeros([data_size, img_size[0], img_size[1], 3], dtype=np.uint8)
    
    for i in tqdm(range(data_size)):
        image_name = images_names[i]
        img_dir = os.path.join(data_dir, image_name+'.jpg')
        img_pixels = tf.keras.preprocessing.image.load_img(img_dir, target_size=img_size)
        X[i] = img_pixels
        
    print('Ouptut data size: ', X.shape)
    return X

test_data = images_to_array2(test_dir, sample_df, img_size)
# Out:
# 100%|██████████| 10357/10357 [00:37<00:00, 278.59it/s]
# Ouptut data size:  (10357, 250, 250, 3)

# %%
#Extract test data features
inception_features = get_features(InceptionV3, inception_preprocessor, img_size, test_data)

test_features = inception_features
print('Final feature maps shape', test_features.shape)
# Out:
# 162/162 [==============================] - 1189s 7s/step
# Feature maps shape:  (10357, 2048)
# Final feature maps shape (10357, 2048)

# %%
y_pred = dnn.predict(test_features, batch_size=128)
# Out:
# 81/81 [==============================] - 0s 3ms/step

# %% [markdown]
# Pisanje rezultata u novi fajl:

# %%
for b in dog_breeds:
    sample_df[b] = y_pred[:,class_to_num[b]]
sample_df.to_csv('/content/submission_predictions.csv', index=None)

# %% [markdown]
# **Literatura**
#
# Keras - https://keras.io/api/applications/inceptionv3/
#
# Papers with code: https://paperswithcode.com/method/inception-v3
#
# Nepreciznost i linarne klasifikacija - https://medium.com/mindorks/classification-problems-with-tensorflow-27eab36aa037
#
# Adam - https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/

# %% [markdown]
# **Zaključak**
#
# Sama izrada projekta je bila veoma interesantna i tokom izrade sam stekao uvid koliko je oblast dubokog učenja kompleksna.
